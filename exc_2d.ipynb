# %% [markdown]
# #2 - d) Problema das Ligas Metálicas

# %% [markdown]
# ##Instaladores e imports

# %%
pip install mip
# Out:
# Collecting mip
#   Downloading https://files.pythonhosted.org/packages/e5/7c/615a417b8b74dde4c3573f09c79612e3e0ed8c9b9488daf67e86cde350d2/mip-1.13.0-py3-none-any.whl (48.0MB)
#      |████████████████████████████████| 48.0MB 90kB/s
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from mip) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->mip) (2.20)
# Installing collected packages: mip
# Successfully installed mip-1.13.0

# %%
from mip import Model, xsum, INTEGER, MAXIMIZE

# %% [markdown]
# ##Dados do sistema

# %%
nvar = 2
obj_coef = [3000, 5000]

g_coef = [[0.5, 0.2], [0.25, 0.3], [0.25, 0.5]]
g_val = [16, 11, 15]

# %% [markdown]
# ##Criação do modelo

# %%
m = Model('Metálicas', sense=MAXIMIZE)

# %% [markdown]
# ##Criação das variáveis do sistema

# %%
x = [m.add_var(name='x{}'.format(int(i)), var_type=INTEGER, lb=0) for i in range(nvar)]

# %% [markdown]
# ##Criação da função objetivo

# %%
m.objective = xsum(obj_coef[i] * x[i] for i in range(nvar))

# %% [markdown]
# ##Restrições do sistema

# %%
for i in range(len(g_val)):
  m += xsum(g_coef[i][j] * x[j] for j in range(nvar)) <= g_val[i]

m += x[0] >=0
m += x[1] >=0

# %%
m.optimize()
# Out:
# <OptimizationStatus.OPTIMAL: 0>

# %% [markdown]
# ##Resultado

# %%
print('Optimize Solution: {}'.format([x[i].x for i in range(nvar)]))
# Out:
# Optimize Solution: [20.0, 20.0]
